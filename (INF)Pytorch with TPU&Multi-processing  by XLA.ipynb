# %% [markdown]
# #Dependencies

# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading https://files.pythonhosted.org/packages/9e/89/d94f59780b5dd973154bf506d8ce598f6bfe7cc44dd445d644d6d3be8c39/timm-0.4.5-py3-none-any.whl (287kB)
#      |████████████████████████████████| 296kB 14.0MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.9.0+cu101)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.8.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (3.7.4.3)
# Installing collected packages: timm
# Successfully installed timm-0.4.5

# %%
# !pip install --upgrade --force-reinstall --no-deps albumentations
# Out:
# Collecting albumentations
#   Downloading https://files.pythonhosted.org/packages/03/58/63fb1d742dc42d9ba2800ea741de1f2bc6bb05548d8724aa84794042eaf2/albumentations-0.5.2-py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 7.5MB/s
# Installing collected packages: albumentations
#   Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# Successfully installed albumentations-0.5.2

# %%
import numpy as np
import os
import time
import random

import torch
import torch.nn as nn
'''
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.distributed.parallel_loader as pl
import torch_xla.distributed.xla_multiprocessing as xmp
'''
from torchvision import datasets, transforms

import pandas as pd
import cv2
from matplotlib import pyplot as plt

import timm

from albumentations import (
    Compose, OneOf, Normalize, Resize, RandomResizedCrop, RandomCrop, HorizontalFlip, VerticalFlip, 
    RandomBrightness, RandomContrast, RandomBrightnessContrast, Rotate, ShiftScaleRotate, Cutout, 
    IAAAdditiveGaussianNoise, Transpose
    )
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingLR
import math
import datetime

#for INF
from tqdm.auto import tqdm

# %% [markdown]
# #Hardware settings

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ##GPU settings

# %% [markdown]
# ##Colab Only

# %%
#Check GPU status
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun Mar 21 10:28:27 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    27W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Check Memory size
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
#Connect Google drive
from google.colab import drive
drive.mount('/content/drive')
! mkdir -p ~/.kaggle
! cp "drive/My Drive/kaggle/kaggle.json" ~/.kaggle/
# !pip install --upgrade --force-reinstall --no-deps kaggle
! kaggle config view
ROOT_DIR="/content/drive/MyDrive"
INPUT_DIR="/kaggle/input"
# %cd $ROOT_DIR$INPUT_DIR
# Out:
# Mounted at /content/drive
# Collecting kaggle
#   Downloading https://files.pythonhosted.org/packages/3a/e7/3bac01547d2ed3d308ac92a0878fbdb0ed0f3d41fb1906c319ccbba1bfbc/kaggle-1.5.12.tar.gz (58kB)
#      |████████████████████████████████| 61kB 6.3MB/s
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-cp37-none-any.whl size=73053 sha256=6dbb0a94653ed5f7026b005511f078a7cd32b2be99a80dc0ac1356ca02dedd3a
#   Stored in directory: /root/.cache/pip/wheels/a1/6a/26/d30b7499ff85a4a4593377a87ecf55f7d08af42f0de9b60303
# Successfully built kaggle
# Installing collected packages: kaggle
#   Found existing installation: kaggle 1.5.10
#     Uninstalling kaggle-1.5.10:
#       Successfully uninstalled kaggle-1.5.10
# Successfully installed kaggle-1.5.12
# Configuration values from /root/.kaggle
# - username: roganzu
# - path: None
# - proxy: None
# - competition: None
# /content/drive/MyDrive/kaggle/input

# %%
def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_torch()

# %% [markdown]
# #Parameters(Non-tuning)

# %%
FLAGS = {}
FLAGS['REPO_NAME'] = 'plant-pathology-2021-fgvc8'
#data
FLAGS['OS_LIST_DIR'] = f"../input/{FLAGS['REPO_NAME']}"
FLAGS['TRAIN_PATH'] = f"{FLAGS['OS_LIST_DIR']}/test_images"
FLAGS['image_size'] = 384
#model
FLAGS['model_name'] = 'resnext50_32x4d'
FLAGS['target_size'] = 12
#output
FLAGS['OUTPUT_DIR'] = f"{ROOT_DIR}/kaggle/output/{FLAGS['REPO_NAME']}/"

# %% [markdown]
# #LoadData

# %%
os.listdir(FLAGS['OS_LIST_DIR'] )
# Out:
# ['sample_submission.csv',
#  'train.csv',
#  'plant-pathology-2021-fgvc8.zip',
#  'test_images',
#  'train_images']

# %%
database_base_path = '../input/plant-pathology-2021-fgvc8/'
train = pd.read_csv(f'{database_base_path}train.csv')
print(f'Train samples: {len(train)}')
# Out:
# Train samples: 18632

# %%
train.head(10)
# Out:
#                   image                           labels
# 0  800113bb65efe69e.jpg                          healthy
# 1  8002cb321f8bfcdf.jpg  scab frog_eye_leaf_spot complex
# 2  80070f7fb5e2ccaa.jpg                             scab
# 3  80077517781fb94f.jpg                             scab
# 4  800cbf0ff87721f8.jpg                          complex
# 5  800edef467d27c15.jpg                          healthy
# 6  800f85dc5f407aef.jpg                 cider_apple_rust
# 7  801d6dcd96e48ebc.jpg                          healthy
# 8  801f78399a44e7af.jpg                          complex
# 9  8021b94d437eb7d3.jpg                          healthy

# %%
test = pd.read_csv(f"../input/{FLAGS['REPO_NAME']}/sample_submission.csv")
print(test.shape)
test.head()
# Out:
# (3, 2)
#                   image   labels
# 0  85f8cb619c66b863.jpg  healthy
# 1  ad8770db05586b59.jpg  healthy
# 2  c7b03e718489f3ca.jpg  healthy

# %%
labels = list(test['labels'].value_counts().keys())
labels_dict = dict(zip(labels, range(12)))
test['labels'] = test['labels'].replace(labels_dict)
test.head()
# Out:
#                   image  labels
# 0  85f8cb619c66b863.jpg       0
# 1  ad8770db05586b59.jpg       0
# 2  c7b03e718489f3ca.jpg       0

# %%
#Update later

# %% [markdown]
# #Model

# %%
class CustomModel(nn.Module):
    def __init__(self, model_name=FLAGS['model_name'], pretrained=True):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained)
        n_features = self.model.fc.in_features
        self.model.fc = nn.Linear(n_features, FLAGS['target_size'])

    def forward(self, x):
        x = self.model(x)
        return x

# %% [markdown]
# ##Transforming

# %%
def get_transforms(*, data): 
        return Compose([
            RandomResizedCrop(FLAGS['image_size'], FLAGS['image_size'], scale=(0.85, 1.0)),
            HorizontalFlip(p=0.5),
            Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %%
class TestDataset(Dataset):
  def __init__(self, df, transform=None):
    self.df = df
    self.file_names = df['image'].values
    self.labels = df['labels'].values
    self.transform = transform
        
  def __len__(self):
    return len(self.df)

  def __getitem__(self, idx):
    file_name = self.file_names[idx]
    file_path = f"{FLAGS['TRAIN_PATH']}/{file_name}"
    image = cv2.imread(file_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    if self.transform:
      augmented = self.transform(image=image)
      image = augmented['image']
      #label = torch.tensor(self.labels[idx]).float()
    return image

# %%
test_dataset = TestDataset(test, transform=get_transforms(data='valid'))

"""
for i in range(3):
    image, label = test_dataset[i]
    plt.imshow(image[0])
    plt.title(f'label: {label}')
    plt.show()
"""
# Out:
# "\nfor i in range(3):\n    image, label = test_dataset[i]\n    plt.imshow(image[0])\n    plt.title(f'label: {label}')\n    plt.show()\n"

# %% [markdown]
# #Inference

# %%
def inference(model, state, test_loader, device):
    model.to(device)
    tk0 = tqdm(enumerate(test_loader), total=len(test_loader))
    probs = []
    for i, (images) in tk0:
        images = images.to(device)
        avg_preds = []
        model.load_state_dict(state)
        model.eval()
        with torch.no_grad():
          y_preds = model(images)
          print(y_preds)
        avg_preds.append(y_preds.argmax(1).to('cpu').numpy())
        avg_preds = np.mean(avg_preds, axis=0)
        probs.append(avg_preds)
    probs = np.concatenate(probs)
    return probs

# %% [markdown]
# #Parameters(Tuning)

# %%
#training
FLAGS['batch_size'] = 16
FLAGS['num_workers'] = 2
FLAGS['learning_rate'] = 0.02
FLAGS['min_lr'] = 0.00002
FLAGS['T_max'] = 60000
FLAGS['weight_decay'] = 0.0001
FLAGS['num_cores'] = 8
FLAGS['num_epochs'] = 10
FLAGS['print_freq'] = 100
FLAGS['max_grad_norm']=1000

# %% [markdown]
# #Execute Main

# %%
model = CustomModel(pretrained=False)
state = torch.load(FLAGS['OUTPUT_DIR']+f"{FLAGS['model_name']}.pth")
test_dataset = TestDataset(test, transform=get_transforms(data='valid'))
test_loader = DataLoader(test_dataset, batch_size=FLAGS['batch_size'], shuffle=False, 
                         num_workers=FLAGS['num_workers'], pin_memory=True)
predictions = inference(model, state, test_loader, device)
# submission
test['labels'] = predictions
test.to_csv(FLAGS['OUTPUT_DIR']+'submission.csv', index=False)
test.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# tensor([[ 1.7174,  3.0881,  0.4402,  4.3796, -2.5064, -0.8513, -2.7504, -6.0274,
#          -6.4565, -1.7974, -5.1204, -8.3114],
#         [ 0.8775,  0.3511,  0.9259, -0.4930,  1.3402,  1.0891,  0.0512, -1.0331,
#          -1.2149, -1.8350, -1.8231, -1.1500],
#         [ 0.8560,  0.3056,  0.9161, -0.5870,  1.4150,  1.1438,  0.1036, -0.9393,
#          -1.1166, -1.8279, -1.7636, -1.0162]], device='cuda:0')
#                   image  labels
# 0  85f8cb619c66b863.jpg     3.0
# 1  ad8770db05586b59.jpg     4.0
# 2  c7b03e718489f3ca.jpg     4.0

# %%
labels = list(train['labels'].value_counts().keys())
labels
# Out:
# ['scab',
#  'healthy',
#  'frog_eye_leaf_spot',
#  'cider_apple_rust',
#  'complex',
#  'powdery_mildew',
#  'scab frog_eye_leaf_spot',
#  'scab frog_eye_leaf_spot complex',
#  'frog_eye_leaf_spot complex',
#  'rust frog_eye_leaf_spot',
#  'rust complex',
#  'powdery_mildew complex']

# %%
labels = list(train['labels'].value_counts().keys())
labels_dict = dict(zip(range(12), labels))
labels_dict
# Out:
# {0: 'scab',
#  1: 'healthy',
#  2: 'frog_eye_leaf_spot',
#  3: 'cider_apple_rust',
#  4: 'complex',
#  5: 'powdery_mildew',
#  6: 'scab frog_eye_leaf_spot',
#  7: 'scab frog_eye_leaf_spot complex',
#  8: 'frog_eye_leaf_spot complex',
#  9: 'rust frog_eye_leaf_spot',
#  10: 'rust complex',
#  11: 'powdery_mildew complex'}

# %%
labels = list(train['labels'].value_counts().keys())
labels_dict = dict(zip(labels, range(12)))
test['labels'] = test['labels'].replace(labels_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-72b2d90ac26f> in <module>()
#       1 labels = list(train['labels'].value_counts().keys())
#       2 labels_dict = dict(zip(labels, range(12)))
# ----> 3 test['labels'] = test['labels'].replace(labels_dict)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4580             limit=limit,
#    4581             regex=regex,
# -> 4582             method=method,
#    4583         )
#    4584
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6505
#    6506             return self.replace(
# -> 6507                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6508             )
#    6509         else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4580             limit=limit,
#    4581             regex=regex,
# -> 4582             method=method,
#    4583         )
#    4584
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6551                         dest_list=value,
#    6552                         inplace=inplace,
# -> 6553                         regex=regex,
#    6554                     )
#    6555
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     649         mask = ~isna(values)
#     650
# --> 651         masks = [comp(s, mask, regex) for s in src_list]
#     652
#     653         result_blocks = []
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     649         mask = ~isna(values)
#     650
# --> 651         masks = [comp(s, mask, regex) for s in src_list]
#     652
#     653         result_blocks = []
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in comp(s, mask, regex)
#     643
#     644             s = com.maybe_box_datetimelike(s)
# --> 645             return _compare_or_regex_search(values, s, regex, mask)
#     646
#     647         # Calculate the mask once, prior to the call of comp
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _compare_or_regex_search(a, b, regex, mask)
#    1999     if is_datetimelike_v_numeric(a, b) or is_numeric_v_string_like(a, b):
#    2000         # GH#29553 avoid deprecation warnings from numpy
# -> 2001         _check_comparison_types(False, a, b)
#    2002         return False
#    2003
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _check_comparison_types(result, a, b)
#    1979
#    1980             raise TypeError(
# -> 1981                 f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1982             )
#    1983
#
# TypeError: Cannot compare types 'ndarray(dtype=float64)' and 'str'
